# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("Movie_collection_train.csv")
df.head()
# Out:
#    Collection  Marketin_expense  Production_expense  Multiplex_coverage  \
# 0       48000           20.1264               59.62               0.462
# 1       43200           20.5462               69.14               0.531
# 2       69400           20.5458               69.14               0.531
# 3       66800           20.6474               59.36               0.542
# 4       72400           21.3810               59.36               0.542
#
#       Budget  Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  \
# 0  36524.125         138.7               7.825                8.095
# 1  35668.655         152.4               7.505                7.650
# 2  39912.675         134.6               7.485                7.570
# 3  38873.890         119.3               6.895                7.035
# 4  39701.585         127.7               6.920                7.070
#
#    Director_rating  Producer_rating  Critic_rating  Trailer_views  Time_taken  \
# ...

# %%
df.columns
# Out:
# Index(['Collection', 'Marketin_expense', 'Production_expense',
#        'Multiplex_coverage', 'Budget', 'Movie_length', 'Lead_ Actor_Rating',
#        'Lead_Actress_rating', 'Director_rating', 'Producer_rating',
#        'Critic_rating', 'Trailer_views', 'Time_taken', 'Twitter_hastags',
#        'Genre', 'Avg_age_actors', 'MPAA_film_rating', 'Num_multiplex',
#        '3D_available'],
#       dtype='object')

# %%
col = ['Collection', 'Marketin_expense', 'Production_expense',
       'Multiplex_coverage', 'Budget', 'Movie_length', 'Lead_ Actor_Rating',
       'Lead_Actress_rating', 'Director_rating', 'Producer_rating',
       'Critic_rating', 'Trailer_views', 'Time_taken', 'Twitter_hastags',
       'Genre', 'Avg_age_actors', 'MPAA_film_rating', 'Num_multiplex',
       '3D_available']
for i in col:
    print(i,'\n',df[i].unique(),'\n','No of unique value:',df[i].nunique(),'\n')
# Out:
# Collection
#  [ 48000  43200  69400  66800  72400  57400  45800  44200  33000  37800
#   30000  43400  40800  36400  39800  46200  35000  40400  27200  39200
#   30400  29000  31200  27800  33200  29600  36800  42000  25400  26400
#   26200  27000  40000  48400  61600  69800  53200  50600  49400  42400
#   38600  28800  38800  39400  41000  50000  46800  70800  63200  46600
#   37400  32000  44400  66000  47000  44000  34800  41800  45600  48200
#   42800  41600  40600  56000  47800  49600  45000  47200  45200  41200
#   56800  77400  87600  66400  55000  53000  37200  40200  39000  39600
#   37600  37000  36600  38400  34600  31400  32400  36000  28600  46000
#   36200  34200  26600  35600  28000  26800  23600  27600  29200  30800
#   43000  30600  34000  82600  48600  54000 100000  45400  47600  44600
#   38200  58800  46400  49200  59800  74400  79600  75800  65000  52800
#   59200  64000  59600  61000  72800  62200  58200  66600  60600  69200
# ...

# %%
df.isnull().sum()
# Out:
# Collection             0
# Marketin_expense       0
# Production_expense     0
# Multiplex_coverage     0
# Budget                 0
# Movie_length           0
# Lead_ Actor_Rating     0
# Lead_Actress_rating    0
# Director_rating        0
# Producer_rating        0
# Critic_rating          0
# Trailer_views          0
# Time_taken             8
# Twitter_hastags        0
# Genre                  0
# Avg_age_actors         0
# MPAA_film_rating       0
# Num_multiplex          0
# 3D_available           0
# dtype: int64

# %%
df.shape
# Out:
# (400, 19)

# %%
df.head()
# Out:
#    Collection  Marketin_expense  Production_expense  Multiplex_coverage  \
# 0       48000           20.1264               59.62               0.462
# 1       43200           20.5462               69.14               0.531
# 2       69400           20.5458               69.14               0.531
# 3       66800           20.6474               59.36               0.542
# 4       72400           21.3810               59.36               0.542
#
#       Budget  Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  \
# 0  36524.125         138.7               7.825                8.095
# 1  35668.655         152.4               7.505                7.650
# 2  39912.675         134.6               7.485                7.570
# 3  38873.890         119.3               6.895                7.035
# 4  39701.585         127.7               6.920                7.070
#
#    Director_rating  Producer_rating  Critic_rating  Trailer_views  Time_taken  \
# ...

# %%
sns.jointplot(x = "Budget",y = "Collection",data = df)

# %%
df.head()
# Out:
#    Collection  Marketin_expense  Production_expense  Multiplex_coverage  \
# 0       48000           20.1264               59.62               0.462
# 1       43200           20.5462               69.14               0.531
# 2       69400           20.5458               69.14               0.531
# 3       66800           20.6474               59.36               0.542
# 4       72400           21.3810               59.36               0.542
#
#       Budget  Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  \
# 0  36524.125         138.7               7.825                8.095
# 1  35668.655         152.4               7.505                7.650
# 2  39912.675         134.6               7.485                7.570
# 3  38873.890         119.3               6.895                7.035
# 4  39701.585         127.7               6.920                7.070
#
#    Director_rating  Producer_rating  Critic_rating  Trailer_views  Time_taken  \
# ...

# %%
sns.countplot(x = "3D_available",data = df)

# %%
sns.countplot(x = "Genre",data= df)

# %%
sns.countplot(x = "MPAA_film_rating",data = df)

# %%
#sns.catplot(x="Time_taken", y="Movie_length", jitter=False, data=df);

# %% [raw]
# ## OBSERVATIONS
#
# >#### Missing values
# >#### Skewness
# >#### Outliers
# >#### MPAA_film_rating has only one value

# %% [markdown]
# #### OUTLIERS TREATMENT

# %%
# Here is 99 is the percentile values
np.percentile(df.Marketin_expense,[99]) #the values is showing in the array form
# Out:
# array([472.15222])

# %%
#Here is showing the values int percentile form
np.percentile(df.Marketin_expense,[99])[0]
# Out:
# 472.1522199999998

# %%
#here i store the data in the new data form uv(upper value)
uv = np.percentile(df.Marketin_expense,[99])[0]

# %%
#here data is showing which is more than 99 percentile in the marketin_expense column
df[(df.Marketin_expense>uv)]
# Out:
#      Collection  Marketin_expense  Production_expense  Multiplex_coverage  \
# 378       26200           492.964                91.2               0.329
# 380       20800          1799.524                91.2               0.329
# 386       21000           507.876                91.2               0.300
# 398       10000           787.036                91.2               0.307
#
#         Budget  Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  \
# 378  35440.900         169.7               9.240                 9.39
# 380  38707.240         165.4               9.170                 9.43
# 386  25841.860         173.5               9.145                 9.32
# 398  30291.415         173.5               9.215                 9.37
#
#      Director_rating  Producer_rating  Critic_rating  Trailer_views  \
# 378            9.235            9.365           6.96         359760
# 380            9.155            9.410           6.96         417588
# ...

# %%
df.Marketin_expense[(df.Marketin_expense> 3*uv)] = 3*uv
# Out:
# C:\Users\Akash Yadav\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# #### LOWER VALUE

# %%
np.percentile(df.Production_expense,[1])[0]# here put "0" bcs we want 1st value array
# Out:
# 57.4994

# %%
# lv is the lower value
lv = np.percentile(df.Production_expense,[1])[0]

# %%
#here we are geting outliers for lower value
df[(df.Production_expense<lv)]
# Out:
#      Collection  Marketin_expense  Production_expense  Multiplex_coverage  \
# 55        70800           20.2622               57.44               0.597
# 56        49400           20.4110               56.48               0.590
# 195      100000           20.2762               55.92               0.578
# 283      100000           20.3002               57.42               0.599
#
#         Budget  Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  \
# 55   40268.195          95.4               5.550                5.795
# 56   35457.565         109.2               5.340                5.535
# 195  43745.625         105.5               7.095                7.235
# 283  44012.265          98.3               6.925                7.080
#
#      Director_rating  Producer_rating  Critic_rating  Trailer_views  \
# 55             5.605            5.655           8.42         512329
# 56             5.285            5.465           8.54         539589
# ...

# %%
df.Marketin_expense[(df.Marketin_expense< 0.3*uv)] = 0.3*uv
# Out:
# C:\Users\Akash Yadav\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
## Lower vlaue

# %%
np.percentile(df.Twitter_hastags,[1])[0]
# Out:
# 202.23968000000002

# %%
uv = np.percentile(df.Twitter_hastags,[1])[0]

# %%
df[(df.Twitter_hastags<uv)]
# Out:
#      Collection  Marketin_expense  Production_expense  Multiplex_coverage  \
# 145       27600        141.645666               94.16               0.129
# 156       26200        141.645666               94.16               0.129
# 381       21800        337.488000               91.20               0.329
# 388       20400        306.674000               91.20               0.300
#
#         Budget  Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  \
# 145  34052.150         173.5               9.155                9.370
# 156  29285.960         167.5               9.005                9.145
# 381  36357.475         172.6               9.110                9.350
# 388  27108.400         173.5               9.115                9.315
#
#      Director_rating  Producer_rating  Critic_rating  Trailer_views  \
# 145            9.140            9.495           8.06         305675
# 156            9.075            9.305           8.06         426057
# ...

# %%
df.Marketin_expense[(df.Twitter_hastags< 0.3*uv)] = 0.3*uv
# Out:
# C:\Users\Akash Yadav\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ###### statistical summary

# %%
# it's showing whole dataset stats summery
df.describe()
# Out:
#           Collection  Marketin_expense  Production_expense  \
# count     400.000000        400.000000          400.000000
# mean    48646.500000        156.364079           73.832700
# std     18308.499136         84.309051           13.023426
# min     10000.000000        141.645666           55.920000
# 25%     37800.000000        141.645666           63.250000
# 50%     45000.000000        141.645666           69.030000
# 75%     56500.000000        141.645666           82.840000
# max    100000.000000       1416.456660          106.300000
#
#        Multiplex_coverage        Budget  Movie_length  Lead_ Actor_Rating  \
# count          400.000000    400.000000    400.000000          400.000000
# mean             0.469881  35197.771537    137.581750            7.810275
# std              0.113920   4075.766926     28.990673            1.088694
# min              0.129000  19781.355000     76.400000            3.840000
# ...

# %%
# Here its showing only one column stats summery
# according to our requirement we can change 
df.Collection.describe()
# Out:
# count       400.000000
# mean      48646.500000
# std       18308.499136
# min       10000.000000
# 25%       37800.000000
# 50%       45000.000000
# 75%       56500.000000
# max      100000.000000
# Name: Collection, dtype: float64

# %% [markdown]
# ###### Missing values Treatment

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 19 columns):
# Collection             400 non-null int64
# Marketin_expense       400 non-null float64
# Production_expense     400 non-null float64
# Multiplex_coverage     400 non-null float64
# Budget                 400 non-null float64
# Movie_length           400 non-null float64
# Lead_ Actor_Rating     400 non-null float64
# Lead_Actress_rating    400 non-null float64
# Director_rating        400 non-null float64
# Producer_rating        400 non-null float64
# Critic_rating          400 non-null float64
# Trailer_views          400 non-null int64
# Time_taken             392 non-null float64
# Twitter_hastags        400 non-null float64
# Genre                  400 non-null object
# Avg_age_actors         400 non-null int64
# MPAA_film_rating       400 non-null object
# Num_multiplex          400 non-null int64
# 3D_available           400 non-null object
# ...

# %%
# This is used to fill the missing values with mean
# The missing values is saved in the 1st wala df.Time_taken
# and then fill the missing values with mean() 
# This method is used for filling some specific columns
df.Time_taken = df.Time_taken.fillna(df.Time_taken.mean())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 19 columns):
# Collection             400 non-null int64
# Marketin_expense       400 non-null float64
# Production_expense     400 non-null float64
# Multiplex_coverage     400 non-null float64
# Budget                 400 non-null float64
# Movie_length           400 non-null float64
# Lead_ Actor_Rating     400 non-null float64
# Lead_Actress_rating    400 non-null float64
# Director_rating        400 non-null float64
# Producer_rating        400 non-null float64
# Critic_rating          400 non-null float64
# Trailer_views          400 non-null int64
# Time_taken             400 non-null float64
# Twitter_hastags        400 non-null float64
# Genre                  400 non-null object
# Avg_age_actors         400 non-null int64
# MPAA_film_rating       400 non-null object
# Num_multiplex          400 non-null int64
# 3D_available           400 non-null object
# ...

# %%
# This method is used for fill the full missing value
#df = df.fillna(df.mean())

# %% [markdown]
# ###### Seasonality in data

# %%
# get dummies variable
df = pd.get_dummies(df)

# %%
df.head()
# Out:
#    Collection  Marketin_expense  Production_expense  Multiplex_coverage  \
# 0       48000        141.645666               59.62               0.462
# 1       43200        141.645666               69.14               0.531
# 2       69400        141.645666               69.14               0.531
# 3       66800        141.645666               59.36               0.542
# 4       72400        141.645666               59.36               0.542
#
#       Budget  Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  \
# 0  36524.125         138.7               7.825                8.095
# 1  35668.655         152.4               7.505                7.650
# 2  39912.675         134.6               7.485                7.570
# 3  38873.890         119.3               6.895                7.035
# 4  39701.585         127.7               6.920                7.070
#
#    Director_rating  Producer_rating  ...  Twitter_hastags  Avg_age_actors  \
# ...

# %%
del df['3D_available_NO']

# %%
df.head()
# Out:
#    Collection  Marketin_expense  Production_expense  Multiplex_coverage  \
# 0       48000        141.645666               59.62               0.462
# 1       43200        141.645666               69.14               0.531
# 2       69400        141.645666               69.14               0.531
# 3       66800        141.645666               59.36               0.542
# 4       72400        141.645666               59.36               0.542
#
#       Budget  Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  \
# 0  36524.125         138.7               7.825                8.095
# 1  35668.655         152.4               7.505                7.650
# 2  39912.675         134.6               7.485                7.570
# 3  38873.890         119.3               6.895                7.035
# 4  39701.585         127.7               6.920                7.070
#
#    Director_rating  Producer_rating  ...  Time_taken  Twitter_hastags  \
# ...

# %%
df.corr()
# Out:
#                      Collection  Marketin_expense  Production_expense  \
# Collection             1.000000         -0.246556           -0.373947
# Marketin_expense      -0.246556          1.000000            0.233389
# Production_expense    -0.373947          0.233389            1.000000
# Multiplex_coverage     0.303971         -0.233381           -0.747325
# Budget                 0.754353         -0.119027           -0.403334
# Movie_length          -0.278718          0.192148            0.609577
# Lead_ Actor_Rating    -0.110412          0.219874            0.668242
# Lead_Actress_rating   -0.109230          0.222287            0.669666
# Director_rating       -0.105234          0.218120            0.668155
# Producer_rating       -0.112257          0.222187            0.672624
# Critic_rating          0.317850         -0.135023           -0.177960
# Trailer_views          0.678691         -0.308817           -0.537165
# ...

# %%
del df['MPAA_film_rating_PG']

# %%
del df['Genre_Thriller']

# %%
df.corr()
# Out:
#                      Collection  Marketin_expense  Production_expense  \
# Collection             1.000000         -0.246556           -0.373947
# Marketin_expense      -0.246556          1.000000            0.233389
# Production_expense    -0.373947          0.233389            1.000000
# Multiplex_coverage     0.303971         -0.233381           -0.747325
# Budget                 0.754353         -0.119027           -0.403334
# Movie_length          -0.278718          0.192148            0.609577
# Lead_ Actor_Rating    -0.110412          0.219874            0.668242
# Lead_Actress_rating   -0.109230          0.222287            0.669666
# Director_rating       -0.105234          0.218120            0.668155
# Producer_rating       -0.112257          0.222187            0.672624
# Critic_rating          0.317850         -0.135023           -0.177960
# Trailer_views          0.678691         -0.308817           -0.537165
# ...

# %% [markdown]
# ### Here calculating all the Test values

# %%
import statsmodels.api as sn

# %%
X = sn.add_constant(df['Budget'])
# Out:
# C:\Users\Akash Yadav\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)

# %%
lm = sn.OLS(df['Collection'],X).fit()

# %%
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             Collection   R-squared:                       0.569
# Model:                            OLS   Adj. R-squared:                  0.568
# Method:                 Least Squares   F-statistic:                     525.5
# Date:                Tue, 14 Jul 2020   Prob (F-statistic):           9.43e-75
# Time:                        16:09:51   Log-Likelihood:                -4324.8
# No. Observations:                 400   AIC:                             8654.
# Df Residuals:                     398   BIC:                             8662.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -7.062e+04   5237.404    -13.485      0.000   -8.09e+04   -6.03e+04
# ...

# %% [markdown]
# ### simple linear regression

# %%
from sklearn.linear_model import LinearRegression

# %%
# this is the one dimentional array
y = df['Budget']

# %%
# for two dimentional array we use double [[]](square bracket) 
X = df[['Collection']]

# %%
lm2 = LinearRegression()

# %%
lm2.fit(X,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# (.intercept) and (.coef) is the intercept
# and the result show the b0 and b1
print(lm2.intercept_,lm2.coef_)
# Out:
# 27028.505321468074 [0.16793122]

# %%
# for more information or help
help(lm2)
# Out:
# Help on LinearRegression in module sklearn.linear_model.base object:
#
# class LinearRegression(LinearModel, sklearn.base.RegressorMixin, sklearn.base.MultiOutputMixin)
#  |  LinearRegression(fit_intercept=True, normalize=False, copy_X=True, n_jobs=None)
#  |
#  |  Ordinary least squares Linear Regression.
#  |
#  |  Parameters
#  |  ----------
#  |  fit_intercept : boolean, optional, default True
#  |      whether to calculate the intercept for this model. If set
#  |      to False, no intercept will be used in calculations
#  |      (e.g. data is expected to be already centered).
#  |
#  |  normalize : boolean, optional, default False
#  |      This parameter is ignored when ``fit_intercept`` is set to False.
#  |      If True, the regressors X will be normalized before regression by
#  |      subtracting the mean and dividing by the l2-norm.
#  |      If you wish to standardize, please use
#  |      :class:`sklearn.preprocessing.StandardScaler` before calling ``fit`` on
# ...

# %%
# this all values is predicted value
lm2.predict(X)
# Out:
# array([35089.20400214, 34283.13413408, 38682.93216395, 38246.31098541,
#        39186.72583149, 36667.75749378, 34719.75531261, 34451.06535659,
#        32570.23566443, 33376.3055325 , 32066.44199689, 33376.3055325 ,
#        34316.72037858, 33880.09920004, 33141.20182098, 33712.16797753,
#        34786.92780162, 32906.09810946, 33812.92671104, 33141.20182098,
#        31596.23457385, 33611.40924402, 32133.6144859 , 31898.51077438,
#        32267.95946391, 31696.99330736, 32603.82190894, 31999.26950789,
#        33208.37430999, 34081.61666706, 31293.95837333, 31898.51077438,
#        31461.88959584, 31428.30335134, 31562.64832935, 33376.3055325 ,
#        33745.75422203, 34081.61666706, 35156.37649115, 37373.06862834,
#        38750.10465295, 35962.44635922, 35525.82518068, 35324.30771366,
#        34148.78915607, 33510.65051051, 33745.75422203, 32603.82190894,
#        31864.92452987, 33544.23675501, 33644.99548852, 33913.68544455,
# ...

# %%
help(sns.jointplot)
# Out:
# Help on function jointplot in module seaborn.axisgrid:
#
# jointplot(x, y, data=None, kind='scatter', stat_func=None, color=None, height=6, ratio=5, space=0.2, dropna=True, xlim=None, ylim=None, joint_kws=None, marginal_kws=None, annot_kws=None, **kwargs)
#     Draw a plot of two variables with bivariate and univariate graphs.
#
#     This function provides a convenient interface to the :class:`JointGrid`
#     class, with several canned plot kinds. This is intended to be a fairly
#     lightweight wrapper; if you need more flexibility, you should use
#     :class:`JointGrid` directly.
#
#     Parameters
#     ----------
#     x, y : strings or vectors
#         Data or names of variables in ``data``.
#     data : DataFrame, optional
#         DataFrame when ``x`` and ``y`` are variable names.
#     kind : { "scatter" | "reg" | "resid" | "kde" | "hex" }, optional
#         Kind of plot to draw.
#     stat_func : callable or None, optional
#         *Deprecated*
# ...

# %%
sns.jointplot(x = df['Collection'], y = df['Budget'], data = df,kind = 'reg')

# %% [markdown]
# ### multiple linear regression

# %%
x_multi = df.drop("Budget",axis = 1)

# %%
x_multi.head()
# Out:
#    Collection  Marketin_expense  Production_expense  Multiplex_coverage  \
# 0       48000        141.645666               59.62               0.462
# 1       43200        141.645666               69.14               0.531
# 2       69400        141.645666               69.14               0.531
# 3       66800        141.645666               59.36               0.542
# 4       72400        141.645666               59.36               0.542
#
#    Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# 0         138.7               7.825                8.095            7.910
# 1         152.4               7.505                7.650            7.440
# 2         134.6               7.485                7.570            7.495
# 3         119.3               6.895                7.035            6.920
# 4         127.7               6.920                7.070            6.815
#
#    Producer_rating  Critic_rating  Trailer_views  Time_taken  Twitter_hastags  \
# ...

# %%
# Dependent variable
y_multi = df["Budget"]

# %%
y_multi.head()
# Out:
# 0    36524.125
# 1    35668.655
# 2    39912.675
# 3    38873.890
# 4    39701.585
# Name: Budget, dtype: float64

# %%
x_multi_cons = sn.add_constant(x_multi)
# Out:
# C:\Users\Akash Yadav\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)

# %%
x_multi_cons.head()
# Out:
#    const  Collection  Marketin_expense  Production_expense  \
# 0    1.0       48000        141.645666               59.62
# 1    1.0       43200        141.645666               69.14
# 2    1.0       69400        141.645666               69.14
# 3    1.0       66800        141.645666               59.36
# 4    1.0       72400        141.645666               59.36
#
#    Multiplex_coverage  Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  \
# 0               0.462         138.7               7.825                8.095
# 1               0.531         152.4               7.505                7.650
# 2               0.531         134.6               7.485                7.570
# 3               0.542         119.3               6.895                7.035
# 4               0.542         127.7               6.920                7.070
#
#    Director_rating  Producer_rating  Critic_rating  Trailer_views  Time_taken  \
# ...

# %%
lm.multi_cons = sn.OLS(y_multi, x_multi_cons).fit()

# %%
lm.multi_cons.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Budget   R-squared:                       0.644
# Model:                            OLS   Adj. R-squared:                  0.626
# Method:                 Least Squares   F-statistic:                     36.14
# Date:                Tue, 14 Jul 2020   Prob (F-statistic):           4.01e-73
# Time:                        16:09:55   Log-Likelihood:                -3685.8
# No. Observations:                 400   AIC:                             7412.
# Df Residuals:                     380   BIC:                             7491.
# Df Model:                          19
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# ...

# %%
lm3 = LinearRegression()

# %%
lm3.fit(x_multi,y_multi)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print(lm3.intercept_,lm3.coef_)
# Out:
# 20936.08872551888 [ 1.32516711e-01  5.70751486e+00 -4.13421817e+01  1.90810607e+02
#   2.71431570e+01 -5.49512129e+03  3.88283012e+03 -2.23959984e+01
#   1.45274391e+03  6.15112423e+01  1.67496994e-02 -4.82091500e+00
#   3.94598940e-01 -1.57609610e+01 -7.22603684e-01  6.94874566e+02
#  -2.17608443e+02 -3.02127182e+02  1.22074897e+02]

# %%
# Her we can asily see that result 
df.describe().transpose()
# Out:
#                      count           mean           std            min  \
# Collection           400.0   48646.500000  18308.499136   10000.000000
# Marketin_expense     400.0     156.364079     84.309051     141.645666
# Production_expense   400.0      73.832700     13.023426      55.920000
# Multiplex_coverage   400.0       0.469881      0.113920       0.129000
# Budget               400.0   35197.771537   4075.766926   19781.355000
# Movie_length         400.0     137.581750     28.990673      76.400000
# Lead_ Actor_Rating   400.0       7.810275      1.088694       3.840000
# Lead_Actress_rating  400.0       7.982812      1.089923       4.035000
# Director_rating      400.0       7.813375      1.093581       3.840000
# Producer_rating      400.0       7.993887      1.088619       4.030000
# Critic_rating        400.0       7.894100      0.672413       6.600000
# Trailer_views        400.0  463223.567500  65225.567649  215432.000000
# ...

# %% [markdown]
# ### Train-test split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(x_multi,y_multi,test_size = 0.2,random_state = 0)

# %%
print(X_train.shape,X_test.shape,y_train.shape,y_test.shape)
# Out:
# (320, 19) (80, 19) (320,) (80,)

# %%
from sklearn.linear_model import LinearRegression 
model = LinearRegression()
model.fit(X_test,y_test)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# ### Result

# %%
result = model.score(X_test, y_test)
print("Accuracy: %.2f%%" % (result*100.0))
# Out:
# Accuracy: 81.05%

# %%
y_test_a = model.predict(X_test)

# %%
y_train_a = model.predict(X_train)

# %%
from sklearn.metrics import r2_score

# %%
# This is used for getting help
r2_score?

# %%
r2_score(y_test,y_test_a)
# Out:
# 0.8104740499662586

# %%
r2_score(y_train, y_train_a)
# Out:
# -0.034648457349466755

# %%
from sklearn import preprocessing

# %%
model_r = preprocessing.StandardScaler().fit(X_train)

# %%
X_train_r = model_r.transform(X_train)

# %%
X_test_r = model_r.transform(X_test)

# %%
from sklearn.linear_model import Ridge

# %%
lm_r = Ridge(alpha = 0.5)
lm_r.fit(X_train,y_train)
# Out:
# Ridge(alpha=0.5, copy_X=True, fit_intercept=True, max_iter=None,
#       normalize=False, random_state=None, solver='auto', tol=0.001)
